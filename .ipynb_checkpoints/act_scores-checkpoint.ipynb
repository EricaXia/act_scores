# %% [markdown]
# ## ACT Scores in California Schools
#
# What factors affect high school students' ACT scores? Are ACT scores correlated with graduation rates? What about drop out rates? Are students' financial situations (poverty rate measured by proxy using free reduced meal program eligibility) correlated with ACT scores?
# <br>
# <br>
# This data was taken from the [California Dept. of Education website](https://www.cde.ca.gov/ds/) for the 2017-2018 school year.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pov = pd.read_csv('data/poverty.csv')
act = pd.read_csv('data/act18.csv')
grad = pd.read_csv('data/grad.txt', sep='\t')

# %%
act.rename(columns={'sname':'School Name'}, inplace=True)
grad.rename(columns={'SchoolName' : 'School Name'}, inplace=True)

# %%
act.dropna(inplace = True, subset = ['School Name'])
pov.dropna(inplace=True, subset = ['School Name'])
grad.dropna(inplace=True, subset=['School Name'])

# %%
act.head()
# Out:
#                                 School Name  \
# 0
# 2    Envision Academy for Arts & Technology
# 3    California School for the Deaf-Fremont
# 5  Alameda Science and Technology Institute
# 6             Nea Community Learning Center
#
#                                                dname    cname  enroll12  \
# 0                                                     Alameda     17476
# 2                 Alameda County Office of Education  Alameda        93
# 3  California School for the Deaf-Fremont (State ...  Alameda        76
# 5                                    Alameda Unified  Alameda        44
# 6                                    Alameda Unified  Alameda        30
#
#    NumTstTakr AvgScrEng AvgScrRead AvgScrMath AvgScrSci NumGE21 PctGE21  \
# 0        4120        25         25         25        24    2879   69.88
# 2          16        20         19         20        20       8   50.00
# 3          26        12         15         15        16       0    0.00
# 5          16        27         28         27        26      15   93.75
# 6           2         *          *          *         *       *       *
#
#       year
# 0  2017-18
# 2  2017-18
# 3  2017-18
# 5  2017-18
# 6  2017-18

# %%
# merge multiple data frames
from functools import reduce
data_frames = [act, pov, grad]
df = reduce(lambda  left,right: pd.merge(left,right,on=['School Name'],
                                            how='inner'), data_frames)

# %%
df.drop_duplicates(subset='School Name', keep='first', inplace=True)

# %%
df = df[df['NumTstTakr'] > 0] # filter by schools with students taking ACT

# %%
act.shape, pov.shape, grad.shape, df.shape 
# we have about 1000 schools in our cleaned data set
# Out:
# ((1745, 12), (1708, 28), (194221, 34), (1043, 72))

# %%
df.head()
# Out:
#                                   School Name  \
# 0      Envision Academy for Arts & Technology
# 56   Alameda Science and Technology Institute
# 100                              Alameda High
# 220                               Albany High
# 288                        REALM Charter High
#
#                                   dname    cname  enroll12  NumTstTakr  \
# 0    Alameda County Office of Education  Alameda        93          16
# 56                      Alameda Unified  Alameda        44          16
# 100                     Alameda Unified  Alameda       447         137
# 220                 Albany City Unified  Alameda       269          91
# 288                    Berkeley Unified  Alameda        86           7
#
#     AvgScrEng AvgScrRead AvgScrMath AvgScrSci NumGE21  ...  \
# 0          20         19         20        20       8  ...
# 56         27         28         27        26      15  ...
# 100        27         27         26        26     120  ...
# 220        29         29         28        27      85  ...
# 288         *          *          *         *       *  ...
#
#     SPED Certificate (Count) SPED Certificate (Rate) GED Completer (Count)  \
# 0                          0                     0.0                     0
# 56                         0                     0.0                     0
# 100                        3                     1.5                     0
# 220                        1                     0.7                     0
# 288                        0                     0.0                     0
#
#      GED Completer (Rate)  Other Transfer (Count)  Other Transfer (Rate)  \
# 0                     0.0                       0                    0.0
# 56                    0.0                       0                    0.0
# 100                   0.0                       0                    0.0
# 220                   0.0                       0                    0.0
# 288                   0.0                       0                    0.0
#
#     Dropout (Count) Dropout (Rate) Still Enrolled (Count)  \
# 0                 3            5.2                      1
# 56                0            0.0                      0
# 100               1            0.5                      0
# 220               4            2.7                      1
# 288               1            2.5                      1
#
#     Still Enrolled (Rate)
# 0                     1.7
# 56                    0.0
# 100                   0.0
# 220                   0.7
# 288                   2.5
#
# [5 rows x 72 columns]

# %%
cols = ['AvgScrEng','AvgScrRead', 'AvgScrMath', 'AvgScrSci']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

df['AvgScrTotal'] = df[['AvgScrEng','AvgScrRead', 'AvgScrMath', 'AvgScrSci']].mean(axis=1)

# %%
# subset data; clean up unused columns
df = df[['School Name', 'dname', 'cname', 'enroll12', 'NumTstTakr', 'AvgScrEng',
       'AvgScrRead', 'AvgScrMath', 'AvgScrSci', 'AvgScrTotal', 'NumGE21', 'PctGE21', 'Adult Ed. HS Diploma (Count)',
       'Adult Ed. HS Diploma (Rate)', 'AggregateLevel', 'County Name', 'District Name', 'Dropout (Count)', 'Dropout (Rate)',
        'Enrollment \n(Ages 5-17)', 'Enrollment \n(K-12)', 'FRPM Count \n(Ages 5-17)', 'FRPM Count \n(K-12)', 'Free Meal \nCount \n(Ages 5-17)',
       'Free Meal \nCount \n(K-12)', 'GED Completer (Count)', 'GED Completer (Rate)', 'Golden State Seal Merit Diploma (Count)',
       'Golden State Seal Merit Diploma (Rate', "Met UC/CSU Grad Req's (Rate)",  'PctGE21', 'Percent (%) \nEligible FRPM \n(Ages 5-17)',
       'Percent (%) \nEligible FRPM \n(K-12)', 'Percent (%) \nEligible Free \n(Ages 5-17)','Percent (%) \nEligible Free \n(K-12)',
       'Regular HS Diploma Graduates (Count)','Regular HS Diploma Graduates (Rate)',
        ]]

# %%
# look at highest scoring schools
# df.sort_values(by = 'AvgScrTotal', ascending = False)

# %%
num = ['NumTstTakr', 'AvgScrEng',
       'AvgScrRead', 'AvgScrMath', 'AvgScrSci', 'AvgScrTotal', 'NumGE21', 'PctGE21', 'Adult Ed. HS Diploma (Count)',
       'Adult Ed. HS Diploma (Rate)', 'AggregateLevel', 'County Name', 'District Name', 'Dropout (Count)', 'Dropout (Rate)',
        'Enrollment \n(Ages 5-17)', 'Enrollment \n(K-12)', 'FRPM Count \n(Ages 5-17)', 'FRPM Count \n(K-12)', 'Free Meal \nCount \n(Ages 5-17)',
       'Free Meal \nCount \n(K-12)', 'GED Completer (Count)', 'GED Completer (Rate)', 'Golden State Seal Merit Diploma (Count)',
       'Golden State Seal Merit Diploma (Rate', "Met UC/CSU Grad Req's (Rate)",  'PctGE21', 'Percent (%) \nEligible FRPM \n(Ages 5-17)',
       'Percent (%) \nEligible FRPM \n(K-12)', 'Percent (%) \nEligible Free \n(Ages 5-17)','Percent (%) \nEligible Free \n(K-12)',
       'Regular HS Diploma Graduates (Count)','Regular HS Diploma Graduates (Rate)',
        ]
for column in num:
    df[column] = df[column].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ### How are ACT Scores and poverty related?

# %%
# Plot
sns.regplot(df['Percent (%) \nEligible Free \n(K-12)'], df['AvgScrTotal'], scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('Free Lunch Eligibility and Average ACT Score')
plt.xlabel('Percentage (%) Eligible for Free Lunch')
plt.ylabel('Average ACT Score')
plt.show()

# %%
g = sns.pairplot(df[[
       'Percent (%) \nEligible Free \n(K-12)', 'FRPM Count \n(K-12)', 'AvgScrTotal']])
g.fig.suptitle('Free Lunch Eligibility and Average ACT Score', y = 1.05)
# Out:
# Text(0.5, 1.05, 'Free Lunch Eligibility and Average ACT Score')

# %% [markdown]
# There appears to be a negative trend between % Eligible for Free Lunch and Average ACT score. If a school has a higher proportion of students eligible for Free Lunch or Reduced Lunch, the average ACT score is likely to be lower. Let's investigate different variables to get a closer look.

# %% [markdown]
# ### How are ACT scores, dropout rates, graduation rates, and poverty rates related?

# %%
# Plot
df['Regular HS Diploma Graduates (Rate)'] = pd.to_numeric(df['Regular HS Diploma Graduates (Rate)'], errors='coerce')
sns.regplot(df['Regular HS Diploma Graduates (Rate)'], df['AvgScrTotal'], scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('HS Graduation Rates and Average ACT Score')
plt.xlabel('Regular HS Diploma Graduates (Rate)')
plt.ylabel('Average ACT Score')
plt.show()

# %%
df['Dropout (Rate)'] = pd.to_numeric(df['Dropout (Rate)'], errors='coerce')
df['Met UC/CSU Grad Req\'s (Rate)'] = pd.to_numeric(df['Met UC/CSU Grad Req\'s (Rate)'], errors='coerce')
f = sns.pairplot(df[[
       'Percent (%) \nEligible Free \n(K-12)', 'Regular HS Diploma Graduates (Rate)', 'Dropout (Rate)', 'Met UC/CSU Grad Req\'s (Rate)', 'AvgScrTotal']])
#f.fig.suptitle('Correlations with Average ACT Score', y = 1.05)

# %% [markdown]
# Like in the previous visualizations, there's a strong negative correlation between percentage eligible for free or reduced lunches and ACT scores. There is a slightly positive trend between HS graduation rate and ACT score and slightly negative trend between dropout rate and ACT score.

# %%
df.to_csv('act_df.csv')
